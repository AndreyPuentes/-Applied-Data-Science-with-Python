# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re as re


CO2=pd.read_csv('Carbon Dioxide Emission Estimates.csv')
ENERGY=pd.read_csv('Production Trade and Supply of Energy.csv')

#DATA CO2

CO2.columns=CO2.iloc[0]
CO2=CO2.drop([0])
CO2.columns=['Region/Area', 'Country', 'Year', 'Series', 'Value', 'Footnotes', 'Source']

#United States
CO2_EEUU=CO2[CO2['Country'] == 'United States of America']
CO2_EEUU=CO2_EEUU.sort_values('Year')
CO2_EEUU['Year']=pd.to_numeric(CO2_EEUU['Year'])
CO2_EEUU['Series - Units'] = CO2_EEUU['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[-1]))
CO2_EEUU['Series - Units'] = CO2_EEUU['Series - Units'].apply(lambda x: (re.split(("[)]"),x)[0]))
CO2_EEUU['Series'] = CO2_EEUU['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[0]))
CO2_EEUU=CO2_EEUU[['Country', 'Year', 'Series', 'Value', 'Series - Units']]
CO2_EEUU=CO2_EEUU[(CO2_EEUU['Series'] == 'Emissions per capita') & (CO2_EEUU['Year'] >= 2005)]
CO2_EEUU

#Russian Federation
CO2_RUSIA=CO2[CO2['Country'] == 'Russian Federation']
CO2_RUSIA=CO2_RUSIA.sort_values('Year')
CO2_RUSIA['Year']=pd.to_numeric(CO2_RUSIA['Year'])
CO2_RUSIA['Series - Units'] = CO2_RUSIA['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[-1]))
CO2_RUSIA['Series - Units'] = CO2_RUSIA['Series - Units'].apply(lambda x: (re.split(("[)]"),x)[0]))
CO2_RUSIA['Series'] = CO2_RUSIA['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[0]))
CO2_RUSIA=CO2_RUSIA[['Country', 'Year', 'Series', 'Value', 'Series - Units']]
CO2_RUSIA=CO2_RUSIA[(CO2_RUSIA['Series'] == 'Emissions per capita') & (CO2_RUSIA['Year'] >= 2005)]
CO2_RUSIA

#FRANCE
CO2_FRANCE=CO2[CO2['Country'] == 'France']
CO2_FRANCE=CO2_FRANCE.sort_values('Year')
CO2_FRANCE['Year']=pd.to_numeric(CO2_FRANCE['Year'])
CO2_FRANCE['Series - Units'] = CO2_FRANCE['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[-1]))
CO2_FRANCE['Series - Units'] = CO2_FRANCE['Series - Units'].apply(lambda x: (re.split(("[)]"),x)[0]))
CO2_FRANCE['Series'] = CO2_FRANCE['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[0]))
CO2_FRANCE=CO2_FRANCE[['Country', 'Year', 'Series', 'Value', 'Series - Units']]
CO2_FRANCE=CO2_FRANCE[(CO2_FRANCE['Series'] == 'Emissions per capita') & (CO2_FRANCE['Year'] >= 2005)]
CO2_FRANCE

#CHINA
CO2_CHINA=CO2[CO2['Country'] == 'China']
CO2_CHINA=CO2_CHINA.sort_values('Year')
CO2_CHINA['Year']=pd.to_numeric(CO2_CHINA['Year'])
CO2_CHINA['Series - Units'] = CO2_CHINA['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[-1]))
CO2_CHINA['Series - Units'] = CO2_CHINA['Series - Units'].apply(lambda x: (re.split(("[)]"),x)[0]))
CO2_CHINA['Series'] = CO2_CHINA['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[0]))
CO2_CHINA=CO2_CHINA[['Country', 'Year', 'Series', 'Value', 'Series - Units']]
CO2_CHINA=CO2_CHINA[(CO2_CHINA['Series'] == 'Emissions per capita') & (CO2_CHINA['Year'] >= 2005)]
CO2_CHINA

#Germany
CO2_GERMANY=CO2[CO2['Country'] == 'Germany']
CO2_GERMANY=CO2_GERMANY.sort_values('Year')
CO2_GERMANY['Year']=pd.to_numeric(CO2_GERMANY['Year'])
CO2_GERMANY['Series - Units'] = CO2_GERMANY['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[-1]))
CO2_GERMANY['Series - Units'] = CO2_GERMANY['Series - Units'].apply(lambda x: (re.split(("[)]"),x)[0]))
CO2_GERMANY['Series'] = CO2_GERMANY['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[0]))
CO2_GERMANY=CO2_GERMANY[['Country', 'Year', 'Series', 'Value', 'Series - Units']]
CO2_GERMANY=CO2_GERMANY[(CO2_GERMANY['Series'] == 'Emissions per capita') & (CO2_GERMANY['Year'] >= 2005)]
CO2_GERMANY

#DATA ENERGY
ENERGY.columns=ENERGY.iloc[0]
ENERGY=ENERGY.drop([0])
ENERGY.columns=['Region/Area', 'Country', 'Year', 'Series', 'Value', 'Footnotes', 'Source']

#United States
ENERGY_EEUU=ENERGY[ENERGY['Country'] == 'United States of America']
ENERGY_EEUU=ENERGY_EEUU.sort_values('Year')
ENERGY_EEUU['Year']=pd.to_numeric(ENERGY_EEUU['Year'])
ENERGY_EEUU['Series - Units'] = ENERGY_EEUU['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[-1]))
ENERGY_EEUU['Series - Units'] = ENERGY_EEUU['Series - Units'].apply(lambda x: (re.split(("[)]"),x)[0]))
ENERGY_EEUU['Series'] = ENERGY_EEUU['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[0]))
ENERGY_EEUU=ENERGY_EEUU[['Country', 'Year', 'Series', 'Value', 'Series - Units']]
ENERGY_EEUU=ENERGY_EEUU[(ENERGY_EEUU['Series'] == 'Supply per capita') & (ENERGY_EEUU['Year'] >= 2005)]

#RUSIA
ENERGY_RUSIA=ENERGY[ENERGY['Country'] == 'Russian Federation']
ENERGY_RUSIA=ENERGY_RUSIA.sort_values('Year')
ENERGY_RUSIA['Year']=pd.to_numeric(ENERGY_RUSIA['Year'])
ENERGY_RUSIA['Series - Units'] = ENERGY_RUSIA['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[-1]))
ENERGY_RUSIA['Series - Units'] = ENERGY_RUSIA['Series - Units'].apply(lambda x: (re.split(("[)]"),x)[0]))
ENERGY_RUSIA['Series'] = ENERGY_RUSIA['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[0]))
ENERGY_RUSIA=ENERGY_RUSIA[['Country', 'Year', 'Series', 'Value', 'Series - Units']]
ENERGY_RUSIA=ENERGY_RUSIA[(ENERGY_RUSIA['Series'] == 'Supply per capita') & (ENERGY_RUSIA['Year'] >= 2005)]

#FRANCE
ENERGY_FRANCE=ENERGY[ENERGY['Country'] == 'France']
ENERGY_FRANCE=ENERGY_FRANCE.sort_values('Year')
ENERGY_FRANCE['Year']=pd.to_numeric(ENERGY_FRANCE['Year'])
ENERGY_FRANCE['Series - Units'] = ENERGY_FRANCE['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[-1]))
ENERGY_FRANCE['Series - Units'] = ENERGY_FRANCE['Series - Units'].apply(lambda x: (re.split(("[)]"),x)[0]))
ENERGY_FRANCE['Series'] = ENERGY_FRANCE['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[0]))
ENERGY_FRANCE=ENERGY_FRANCE[['Country', 'Year', 'Series', 'Value', 'Series - Units']]
ENERGY_FRANCE=ENERGY_FRANCE[(ENERGY_FRANCE['Series'] == 'Supply per capita') & (ENERGY_FRANCE['Year'] >= 2005)]
ENERGY_FRANCE

#CHINA
ENERGY_CHINA=ENERGY[ENERGY['Country'] == 'China']
ENERGY_CHINA=ENERGY_CHINA.sort_values('Year')
ENERGY_CHINA['Year']=pd.to_numeric(ENERGY_CHINA['Year'])
ENERGY_CHINA['Series - Units'] = ENERGY_CHINA['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[-1]))
ENERGY_CHINA['Series - Units'] = ENERGY_CHINA['Series - Units'].apply(lambda x: (re.split(("[)]"),x)[0]))
ENERGY_CHINA['Series'] = ENERGY_CHINA['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[0]))
ENERGY_CHINA=ENERGY_CHINA[['Country', 'Year', 'Series', 'Value', 'Series - Units']]
ENERGY_CHINA=ENERGY_CHINA[(ENERGY_CHINA['Series'] == 'Supply per capita') & (ENERGY_CHINA['Year'] >= 2005)]
ENERGY_CHINA

#GERMANY
ENERGY_GERMANY=ENERGY[ENERGY['Country'] == 'Germany']
ENERGY_GERMANY=ENERGY_GERMANY.sort_values('Year')
ENERGY_GERMANY['Year']=pd.to_numeric(ENERGY_GERMANY['Year'])
ENERGY_GERMANY['Series - Units'] = ENERGY_GERMANY['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[-1]))
ENERGY_GERMANY['Series - Units'] = ENERGY_GERMANY['Series - Units'].apply(lambda x: (re.split(("[)]"),x)[0]))
ENERGY_GERMANY['Series'] = ENERGY_GERMANY['Series'].apply(lambda x: (re.split(("([\s][()])"),x)[0]))
ENERGY_GERMANY=ENERGY_GERMANY[['Country', 'Year', 'Series', 'Value', 'Series - Units']]
ENERGY_GERMANY=ENERGY_GERMANY[(ENERGY_GERMANY['Series'] == 'Supply per capita') & (ENERGY_GERMANY['Year'] >= 2005)]
ENERGY_GERMANY


EEUU_CO2=pd.to_numeric(CO2_EEUU['Value'])
RUSIA_CO2=pd.to_numeric(CO2_RUSIA['Value'])
FRANCE_CO2=pd.to_numeric(CO2_FRANCE['Value'])
CHINA_CO2=pd.to_numeric(CO2_CHINA['Value'])
GERMANY_CO2=pd.to_numeric(CO2_GERMANY['Value'])
YEAR=pd.to_numeric(CO2_GERMANY['Year'])

EEUU_ENERGY=pd.to_numeric(ENERGY_EEUU['Value'])
RUSIA_ENERGY=pd.to_numeric(ENERGY_RUSIA['Value'])
FRANCE_ENERGY=pd.to_numeric(ENERGY_FRANCE['Value'])
CHINA_ENERGY=pd.to_numeric(ENERGY_CHINA['Value'])
GERMANY_ENERGY=pd.to_numeric(ENERGY_GERMANY['Value'])

plt.figure(figsize=(14,9))

plt.subplot(2, 1, 1)
plt.plot(YEAR, EEUU_ENERGY, label='EEUU')
plt.plot(YEAR, RUSIA_ENERGY, label='RUSIA')
plt.plot(YEAR, FRANCE_ENERGY, label='FRANCE')
plt.plot(YEAR, CHINA_ENERGY, label='CHINA')
plt.plot(YEAR, GERMANY_ENERGY, label='GERMANY')
# plt.xlabel('Year', size=8)
plt.ylabel('Energy (Petajoules)', size=14)
plt.title('Comparison of Energy supply and Emission of CO2 per capita by country',  size=18)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().axis([2005,2018,0,340])
# plt.legend(loc='best', fontsize=4)
# plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left', fontsize=8)


plt.subplot(2, 1, 2)
plt.plot(YEAR, EEUU_CO2, label='EEUU')
plt.plot(YEAR, RUSIA_CO2, label='RUSIA')
plt.plot(YEAR, FRANCE_CO2, label='FRANCE')
plt.plot(YEAR, CHINA_CO2, label='CHINA')
plt.plot(YEAR, GERMANY_CO2, label='GERMANY')
plt.xlabel('Year', size=14)
plt.ylabel('Metric tons of CO2', size=14)
# plt.title('Comparative Emission of CO2 per capita by country', size=12)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().axis([2005,2018,0,20])
plt.legend(loc='lower center', fontsize=11, ncol=5)
